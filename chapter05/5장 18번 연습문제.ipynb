# %% [markdown]
# # 5장 18번 연습문제

# %% [markdown]
# 다음의 이진트리에 대하여 질문에 답하라.

# %% [markdown]
# ![KakaoTalk_20240514_171744704_02.jpg](attachment:KakaoTalk_20240514_171744704_02.jpg)

# %% [markdown]
# (1). 이 트리를 전위 순회한 결과를 적어라.
# 1, 2, 4, 8, 9, 5, 10, 11, 3, 6, 7
#
# (2). 이 트리를 중위 순회한 결과를 적어라.
# 8, 4, 9, 2, 10, 5, 11, 1, 6, 3, 7
#
# (3). 이 트리를 후위 순회한 결과를 적어라.
# 8, 9, 4, 10, 11, 5, 2, 6, 7, 3, 1
