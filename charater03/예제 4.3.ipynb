# %% [markdown]
# # 예제 4.3

# %% [markdown]
# 삽입 정렬

# %% [markdown]
# # 알고리즘 설명

# %% [markdown]
# 자료 배열의 모든 요소를 앞에서부터 차례대로 이미 정렬된 배열 부분과 비교 하여, 자신의ㅣ 위치를 찾아 삽입함으로써 정렬을 완성하는 알고리즘이다.

# %% [markdown]
# # 손으로 푼 예제

# %% [markdown]
# ![KakaoTalk_20240423_025528507.jpg](attachment:KakaoTalk_20240423_025528507.jpg)

# %% [markdown]
# # 알고리즘 개요

# %% [markdown]
# 코드 개요(입력 변수, 출력, 함수 설명)
# 입력 변수 : data = [5, 3, 8, 4, 1, 6, 2, 7]
#
# 출력 :
# Original :  [5, 3, 8, 4, 9, 1, 6, 2, 7]
# step  1 = [3, 5, 8, 4, 9, 1, 6, 2, 7]
# step  2 = [3, 5, 8, 4, 9, 1, 6, 2, 7]
# step  3 = [3, 4, 5, 8, 9, 1, 6, 2, 7]
# step  4 = [3, 4, 5, 8, 9, 1, 6, 2, 7]
# step  5 = [1, 3, 4, 5, 8, 9, 6, 2, 7]
# step  6 = [1, 3, 4, 5, 6, 8, 9, 2, 7]
# step  7 = [1, 2, 3, 4, 5, 6, 8, 9, 7]
# step  8 = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Insertion : [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# # 알고리즘 코드

# %%
def insertion_sort(A) :
    n = len(A)
    for i in range(1, n) :
       key = A[i]
       j = i-1
       while j>=0 and A[j] > key :
        A[j + 1] = A[j]
        j = j - 1
       A[j + 1] = key
       printstep(A, i)

# %% [markdown]
# # 테스트 코드

# %%
def printstep(arr, val) :
    print( "step %2d = " %val, end= '')
    print(arr)


data = [ 5, 3, 8, 4, 9, 1, 6, 2, 7 ]
print("Original : ", data)
insertion_sort(data)
print("Insertion :", data)
# Out:
# Original :  [5, 3, 8, 4, 9, 1, 6, 2, 7]
# step  1 = [3, 5, 8, 4, 9, 1, 6, 2, 7]
# step  2 = [3, 5, 8, 4, 9, 1, 6, 2, 7]
# step  3 = [3, 4, 5, 8, 9, 1, 6, 2, 7]
# step  4 = [3, 4, 5, 8, 9, 1, 6, 2, 7]
# step  5 = [1, 3, 4, 5, 8, 9, 6, 2, 7]
# step  6 = [1, 3, 4, 5, 6, 8, 9, 2, 7]
# step  7 = [1, 2, 3, 4, 5, 6, 8, 9, 7]
# step  8 = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Insertion : [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# # 수행 결과

# %% [markdown]
# ![dfsdfserw.PNG](attachment:dfsdfserw.PNG)

# %% [markdown]
# # 복잡도 함수

# %% [markdown]
# 1. 최선의 경우 시간 복잡도는 O(n) 이다.
# 2. 최악의 경우 O(n2)이고 많은 항목을 이동해야 하므로 레코드의 크기가 큰 경우에 효율적이지 않다.
